# %% [markdown]
# <a href="https://colab.research.google.com/github/agnislur/ndn_project/blob/main/OlahData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
log31=pd.read_csv("log-skenario3-1.csv", index_col=False)
log32=pd.read_csv("log-skenario3-2-benerin2.csv", index_col=False)
log33=pd.read_csv("log-skenario3-3.csv", index_col=False)

log21=pd.read_csv("log-skenario2-1-benerin2.csv", index_col=False)
log22=pd.read_csv("log-skenario2-2.csv", index_col=False)
log23=pd.read_csv("log-skenario2-3-benerin3.csv", index_col=False)

log11=pd.read_csv("log-skenario1-1.csv", index_col=False)
log12=pd.read_csv("log-skenario1-2.csv", index_col=False)
log13=pd.read_csv("log-skenario1-3.csv", index_col=False)

log111=pd.read_csv("interest-skenario1-1.csv", index_col=False)
log122=pd.read_csv("interest-skenario1-2.csv", index_col=False)
log133=pd.read_csv("interest-skenario1-3.csv", index_col=False)

log211=pd.read_csv("interest-skenario2-1-benerin2.csv", index_col=False)
log222=pd.read_csv("interest-skenario2-2.csv", index_col=False)
log233=pd.read_csv("interest-skenario2-3-benerin3.csv", index_col=False)

log311=pd.read_csv("interest-skenario3-1.csv", index_col=False)
log322=pd.read_csv("interest-skenario3-2-benerin2.csv", index_col=False)
log333=pd.read_csv("interest-skenario3-3.csv", index_col=False)

# %%
log31
# Out:
#     PatternID  InterestSent  ResponsesReceived  Nacks  InterestLoss(%)  \
# 0     Overall         10000              10000      0              0.0
# 1           1           531                531      0              0.0
# 2           2           428                428      0              0.0
# 3           3           379                379      0              0.0
# 4           4           377                377      0              0.0
# ..        ...           ...                ...    ...              ...
# 96         96            37                 37      0              0.0
# 97         97            40                 40      0              0.0
# 98         98            49                 49      0              0.0
# 99         99            34                 34      0              0.0
# 100       100            37                 37      0              0.0
#
#      Inconsistency(%)  TotalRTT(ms)  AverageRTT(ms)
# 0                 0.0  39597.765886        3.959777
# ...

# %%
log111
# Out:
#                                                interest    rtt(ms)
# 0     /skenario1--1/traffic67?MustBeFresh&Nonce=5882...  11.171090
# 1     /skenario1--1/traffic76?MustBeFresh&Nonce=2811...  10.495033
# 2     /skenario1--1/traffic12?MustBeFresh&Nonce=c8f5...  10.107645
# 3     /skenario1--1/traffic13?MustBeFresh&Nonce=27c0...   8.132515
# 4     /skenario1--1/traffic94?MustBeFresh&Nonce=bf60...   8.820279
# ...                                                 ...        ...
# 9995  /skenario1--1/traffic41?MustBeFresh&Nonce=dab1...   7.122797
# 9996  /skenario1--1/traffic41?MustBeFresh&Nonce=fb63...   5.872852
# 9997  /skenario1--1/traffic55?MustBeFresh&Nonce=3964...   6.542804
# 9998  /skenario1--1/traffic89?MustBeFresh&Nonce=97e9...   7.580166
# 9999  /skenario1--1/traffic26?MustBeFresh&Nonce=1db8...   7.094678
#
# [10000 rows x 2 columns]

# %% [markdown]
# **CPU Usage R1**

# %%
sys11r2=pd.read_csv("skenario1-r2-1.csv", index_col=False)
sys11r2
# Out:
#                         Time  CPU used   RAM used      VRAM used
# 0   Fri Oct  6 06:24:23 2023       NaN  926167040  1099494850560
# 1   Fri Oct  6 06:24:24 2023  0.000000  926117888  1099494850560
# 2   Fri Oct  6 06:24:25 2023  0.000000  926117888  1099494850560
# 3   Fri Oct  6 06:24:26 2023  0.000000  926117888  1099494850560
# 4   Fri Oct  6 06:24:27 2023  0.000000  926117888  1099494850560
# 5   Fri Oct  6 06:24:28 2023  0.000000  926117888  1099494850560
# 6   Fri Oct  6 06:24:29 2023  0.000000  926117888  1099494850560
# 7   Fri Oct  6 06:24:30 2023  0.000000  926117888  1099494850560
# 8   Fri Oct  6 06:24:31 2023  1.265823  926117888  1099494850560
# 9   Fri Oct  6 06:24:32 2023  1.017812  926117888  1099494850560
# 10  Fri Oct  6 06:24:33 2023  1.767677  926117888  1099494850560
# 11  Fri Oct  6 06:24:34 2023  1.767677  926117888  1099494850560
# 12  Fri Oct  6 06:24:35 2023  1.518987  926117888  1099494850560
# ...

# %%
sys11r2.dropna(subset=['CPU used'], inplace=True)

# %%
sys11r2['Time'] = pd.to_datetime(sys11r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
plt.plot(sys11r2['Time'], sys11r2['CPU used'], label='CPU used', marker='o')
#plt.plot(sys11r2['Time'], sys11r2[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('CPU Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys11r2['Time'] = pd.to_datetime(sys11r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys11r2['Time'], sys11r2['CPU used'], label='CPU used', marker='o')
plt.plot(sys11r2['Time'], sys11r2[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys12r2=pd.read_csv("skenario1-r2-2.csv", index_col=False)
sys12r2
# Out:
#                          Time  CPU used   RAM used      VRAM used
# 0    Fri Oct  6 06:47:01 2023       NaN  931213312  1099494850560
# 1    Fri Oct  6 06:47:02 2023      0.00  931213312  1099494850560
# 2    Fri Oct  6 06:47:03 2023      0.00  931213312  1099494850560
# 3    Fri Oct  6 06:47:04 2023      0.25  931213312  1099494850560
# 4    Fri Oct  6 06:47:05 2023      0.00  931213312  1099494850560
# ..                        ...       ...        ...            ...
# 238  Fri Oct  6 06:50:59 2023      0.00  803860480  1099494850560
# 239  Fri Oct  6 06:51:00 2023      0.00  803860480  1099494850560
# 240  Fri Oct  6 06:51:01 2023      0.25  803860480  1099494850560
# 241  Fri Oct  6 06:51:02 2023      0.00  803852288  1099494850560
# 242  Fri Oct  6 06:51:03 2023      0.00  803852288  1099494850560
#
# [243 rows x 4 columns]

# %%
sys12r2.dropna(subset=['CPU used'], inplace=True)

# %%
sys12r2['Time'] = pd.to_datetime(sys12r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys12r1['Time'], sys12r1['CPU used'], label='CPU used', marker='o')
plt.plot(sys12r2['Time'], sys12r2[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys13r2=pd.read_csv("skenario1-r2-3.csv", index_col=False)
sys13r2
# Out:
#                         Time  CPU used    RAM used   VRAM used
# 0   Fri Oct  6 09:31:57 2023       NaN  1188737024           0
# 1   Fri Oct  6 09:31:58 2023  0.000000  1188687872           0
# 2   Fri Oct  6 09:31:59 2023  0.000000  1188687872           0
# 3   Fri Oct  6 09:32:00 2023  0.000000  1188687872           0
# 4   Fri Oct  6 09:32:01 2023  0.000000  1188687872           0
# 5   Fri Oct  6 09:32:02 2023  0.000000  1188687872           0
# 6   Fri Oct  6 09:32:03 2023  0.000000  1188687872           0
# 7   Fri Oct  6 09:32:04 2023  0.000000  1188687872           0
# 8   Fri Oct  6 09:32:05 2023  0.000000  1188687872           0
# 9   Fri Oct  6 09:32:06 2023  0.000000  1188687872           0
# 10  Fri Oct  6 09:32:07 2023  0.000000  1188687872           0
# 11  Fri Oct  6 09:32:08 2023  0.000000  1188687872           0
# 12  Fri Oct  6 09:32:09 2023  0.000000  1188687872           0
# 13  Fri Oct  6 09:32:10 2023  0.000000  1188687872           0
# ...

# %%
sys13r2.dropna(subset=['CPU used'], inplace=True)

# %%
sys13r2['Time'] = pd.to_datetime(sys13r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys13r1['Time'], sys13r1['CPU used'], label='CPU used', marker='o')
plt.plot(sys13r2['Time'], sys13r2[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys21r2=pd.read_csv("skenario2-r2-1.csv", index_col=False)
sys21r2
# Out:
#                          Time  CPU used    RAM used   VRAM used
# 0    Fri Oct  6 09:38:54 2023    100.00  1188876288           0
# 1    Fri Oct  6 09:38:55 2023      0.00  1188876288           0
# 2    Fri Oct  6 09:38:56 2023      0.00  1188827136           0
# 3    Fri Oct  6 09:38:57 2023      0.00  1188827136           0
# 4    Fri Oct  6 09:38:58 2023      0.00  1188827136           0
# ..                        ...       ...         ...         ...
# 247  Fri Oct  6 09:43:01 2023      0.00  1189085184           0
# 248  Fri Oct  6 09:43:02 2023      0.00  1189085184           0
# 249  Fri Oct  6 09:43:03 2023      0.00  1189085184           0
# 250  Fri Oct  6 09:43:04 2023      0.25  1189085184           0
# 251  Fri Oct  6 09:43:05 2023      0.00  1189085184           0
#
# [252 rows x 4 columns]

# %%
sys21r2.dropna(subset=['CPU used'], inplace=True)

# %%
sys21r2['Time'] = pd.to_datetime(sys21r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys21r1['Time'], sys21r1['CPU used'], label='CPU used', marker='o')
plt.plot(sys21r2['Time'], sys21r2[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys22r2=pd.read_csv("skenario2-r2-2.csv", index_col=False)
sys22r2
# Out:
#                         Time  CPU used    RAM used   VRAM used
# 0   Fri Oct  6 09:47:05 2023       NaN  1190264832           0
# 1   Fri Oct  6 09:47:06 2023  0.000000  1190264832           0
# 2   Fri Oct  6 09:47:07 2023  0.000000  1190264832           0
# 3   Fri Oct  6 09:47:08 2023  0.000000  1190264832           0
# 4   Fri Oct  6 09:47:09 2023  0.000000  1190264832           0
# ..                       ...       ...         ...         ...
# 85  Fri Oct  6 09:48:30 2023  0.000000  1190264832           0
# 86  Fri Oct  6 09:48:31 2023  1.007557  1190264832           0
# 87  Fri Oct  6 09:48:32 2023  0.000000  1190264832           0
# 88  Fri Oct  6 09:48:33 2023  0.000000  1190264832           0
# 89  Fri Oct  6 09:48:34 2023  0.250000  1190264832           0
#
# [90 rows x 4 columns]

# %%
sys22r2.dropna(subset=['CPU used'], inplace=True)

# %%
sys22r2['Time'] = pd.to_datetime(sys22r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys22r1['Time'], sys22r1['CPU used'], label='CPU used', marker='o')
plt.plot(sys22r2['Time'], sys22r2[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys23r2=pd.read_csv("skenario2-r2-3.csv", index_col=False)
sys23r2
# Out:
#                          Time  CPU used    RAM used   VRAM used
# 0    Fri Oct  6 09:52:32 2023  0.000000  1189371904           0
# 1    Fri Oct  6 09:52:33 2023  0.249377  1189371904           0
# 2    Fri Oct  6 09:52:34 2023  0.000000  1189314560           0
# 3    Fri Oct  6 09:52:35 2023  0.000000  1189314560           0
# 4    Fri Oct  6 09:52:36 2023  0.000000  1189314560           0
# ..                        ...       ...         ...         ...
# 223  Fri Oct  6 09:56:15 2023  0.000000  1189572608           0
# 224  Fri Oct  6 09:56:16 2023  0.000000  1189572608           0
# 225  Fri Oct  6 09:56:17 2023  0.000000  1189572608           0
# 226  Fri Oct  6 09:56:18 2023  0.000000  1189572608           0
# 227  Fri Oct  6 09:56:19 2023  0.000000  1189572608           0
#
# [228 rows x 4 columns]

# %%
sys23r2.dropna(subset=['CPU used'], inplace=True)

# %%
sys23r2['Time'] = pd.to_datetime(sys23r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys23r1['Time'], sys23r1['CPU used'], label='CPU used', marker='o')
plt.plot(sys23r2['Time'], sys23r2[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys31r1=pd.read_csv("skenario3-1.csv", index_col=False)
sys31r1
# Out:
#                           Time  CPU used    RAM used   VRAM used
# 0     Fri Oct  6 10:01:30 2023       NaN  1223602176           0
# 1     Fri Oct  6 10:01:31 2023       0.0  1223593984           0
# 2     Fri Oct  6 10:01:32 2023       0.0  1223593984           0
# 3     Fri Oct  6 10:01:33 2023       0.0  1223593984           0
# 4     Fri Oct  6 10:01:34 2023       0.0  1223593984           0
# ...                        ...       ...         ...         ...
# 1175  Fri Oct  6 10:21:06 2023       0.0  1224110080           0
# 1176  Fri Oct  6 10:21:07 2023       0.0  1224110080           0
# 1177  Fri Oct  6 10:21:08 2023       0.0  1224110080           0
# 1178  Fri Oct  6 10:21:09 2023       0.0  1224110080           0
# 1179  Fri Oct  6 10:21:10 2023       0.0  1224110080           0
#
# [1180 rows x 4 columns]

# %%
sys31r1.dropna(subset=['CPU used'], inplace=True)

# %%
sys31r1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1179 entries, 1 to 1179
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Time        1179 non-null   datetime64[ns]
#  1   CPU used    1179 non-null   float64
#  2    RAM used   1179 non-null   int64
#  3    VRAM used  1179 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 46.1 KB

# %%
sys31r1['Time'] = pd.to_datetime(sys31r1['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys31r1['Time'], sys31r1['CPU used'], label='CPU used', marker='o')
plt.plot(sys31r1['Time'], sys31r1[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys32r1=pd.read_csv("skenario3-r1-2.csv", index_col=False)
sys32r1
# Out:
#                          Time  CPU used    RAM used   VRAM used
# 0    Fri Oct  6 10:28:08 2023       NaN  1225482240           0
# 1    Fri Oct  6 10:28:09 2023       0.0  1225482240           0
# 2    Fri Oct  6 10:28:10 2023       0.0  1225433088           0
# 3    Fri Oct  6 10:28:11 2023       0.0  1225433088           0
# 4    Fri Oct  6 10:28:12 2023       0.0  1225433088           0
# ..                        ...       ...         ...         ...
# 129  Fri Oct  6 10:30:17 2023       0.0  1225691136           0
# 130  Fri Oct  6 10:30:18 2023       0.0  1225691136           0
# 131  Fri Oct  6 10:30:19 2023       0.0  1225691136           0
# 132  Fri Oct  6 10:30:20 2023       0.0  1225691136           0
# 133  Fri Oct  6 10:30:21 2023       0.0  1225691136           0
#
# [134 rows x 4 columns]

# %%
sys32r1.dropna(subset=['CPU used'], inplace=True)

# %%
sys32r1['Time'] = pd.to_datetime(sys32r1['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys32r1['Time'], sys32r1['CPU used'], label='CPU used', marker='o')
plt.plot(sys32r1['Time'], sys32r1[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys33r1=pd.read_csv("skenario3-r1-3.csv", index_col=False)
sys33r1
# Out:
#                         Time    CPU used    RAM used   VRAM used
# 0   Fri Oct  6 10:35:03 2023  100.000000  1225191424           0
# 1   Fri Oct  6 10:35:04 2023    0.000000  1225191424           0
# 2   Fri Oct  6 10:35:05 2023    0.000000  1225191424           0
# 3   Fri Oct  6 10:35:06 2023    0.000000  1225191424           0
# 4   Fri Oct  6 10:35:07 2023    0.000000  1225191424           0
# 5   Fri Oct  6 10:35:08 2023    0.000000  1225191424           0
# 6   Fri Oct  6 10:35:09 2023    0.000000  1225191424           0
# 7   Fri Oct  6 10:35:10 2023    0.000000  1225191424           0
# 8   Fri Oct  6 10:35:11 2023    0.000000  1225191424           0
# 9   Fri Oct  6 10:35:12 2023    0.000000  1225191424           0
# 10  Fri Oct  6 10:35:13 2023    0.000000  1225191424           0
# 11  Fri Oct  6 10:35:14 2023    0.000000  1225191424           0
# 12  Fri Oct  6 10:35:15 2023    0.000000  1225191424           0
# ...

# %%
# Hapus baris dengan nilai 100 pada kolom 'cpu_usage'
sys33r1 = sys33r1[sys33r1['CPU used'] != 100]

print(sys33r1)
# Out:
#                         Time  CPU used    RAM used   VRAM used
# 1   Fri Oct  6 10:35:04 2023  0.000000  1225191424           0
# 2   Fri Oct  6 10:35:05 2023  0.000000  1225191424           0
# 3   Fri Oct  6 10:35:06 2023  0.000000  1225191424           0
# 4   Fri Oct  6 10:35:07 2023  0.000000  1225191424           0
# 5   Fri Oct  6 10:35:08 2023  0.000000  1225191424           0
# 6   Fri Oct  6 10:35:09 2023  0.000000  1225191424           0
# 7   Fri Oct  6 10:35:10 2023  0.000000  1225191424           0
# 8   Fri Oct  6 10:35:11 2023  0.000000  1225191424           0
# 9   Fri Oct  6 10:35:12 2023  0.000000  1225191424           0
# 10  Fri Oct  6 10:35:13 2023  0.000000  1225191424           0
# 11  Fri Oct  6 10:35:14 2023  0.000000  1225191424           0
# 12  Fri Oct  6 10:35:15 2023  0.000000  1225191424           0
# 13  Fri Oct  6 10:35:16 2023  0.000000  1225191424           0
# 14  Fri Oct  6 10:35:17 2023  0.000000  1225191424           0
# ...

# %%
sys33r1.dropna(subset=['CPU used'], inplace=True)

# %%
sys33r1['Time'] = pd.to_datetime(sys33r1['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys33r1['Time'], sys33r1['CPU used'], label='CPU used', marker='o')
plt.plot(sys33r1['Time'], sys33r1[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %% [markdown]
# **CPU usage R2**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-44aa2530-1fe4-4d3b-bea9-8b1dddea4845" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44aa2530-1fe4-4d3b-bea9-8b1dddea4845">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sys33r2=pd.read_csv("skenario3-3.csv", index_col=False)
sys33r2
# Out:
#                          Time  CPU used    RAM used      VRAM used
# 0    Fri Oct  6 10:35:08 2023       NaN  1194635264  1099494850560
# 1    Fri Oct  6 10:35:09 2023  0.000000  1194635264  1099494850560
# 2    Fri Oct  6 10:35:10 2023  0.000000  1194635264  1099494850560
# 3    Fri Oct  6 10:35:11 2023  0.000000  1194635264  1099494850560
# 4    Fri Oct  6 10:35:12 2023  0.000000  1194635264  1099494850560
# ..                        ...       ...         ...            ...
# 114  Fri Oct  6 10:36:12 2023  0.250000  1194627072              0
# 115  Fri Oct  6 10:36:13 2023  0.000000  1194627072              0
# 116  Fri Oct  6 10:36:14 2023  0.000000  1194627072              0
# 117  Fri Oct  6 10:36:15 2023  0.000000  1194627072              0
# 118  Fri Oct  6 10:36:16 2023  0.249377  1194627072              0
#
# [119 rows x 4 columns]

# %%
sys33r2.isna().sum()
# Out:
# Time          1
# CPU used      1
#  RAM used     0
#  VRAM used    0
# dtype: int64

# %%
sys33r2['Time'] = pd.to_datetime(sys33r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
plt.plot(sys33r2['Time'], sys33r2[' RAM used'], label='RAM used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys21r2 = sys21r2[sys21r2['CPU used'] != 100]
print(sys21r2)
# Out:
#                          Time  CPU used    RAM used   VRAM used
# 1    Fri Oct  6 09:38:55 2023      0.00  1188876288           0
# 2    Fri Oct  6 09:38:56 2023      0.00  1188827136           0
# 3    Fri Oct  6 09:38:57 2023      0.00  1188827136           0
# 4    Fri Oct  6 09:38:58 2023      0.00  1188827136           0
# 5    Fri Oct  6 09:38:59 2023      0.00  1188827136           0
# ..                        ...       ...         ...         ...
# 247  Fri Oct  6 09:43:01 2023      0.00  1189085184           0
# 248  Fri Oct  6 09:43:02 2023      0.00  1189085184           0
# 249  Fri Oct  6 09:43:03 2023      0.00  1189085184           0
# 250  Fri Oct  6 09:43:04 2023      0.25  1189085184           0
# 251  Fri Oct  6 09:43:05 2023      0.00  1189085184           0
#
# [251 rows x 4 columns]

# %%
sys21r2=pd.read_csv("skenario2-r2-1-benerin2.csv", index_col=False)

# %%
sys21r2
# Out:
#                         Time  CPU used    RAM used      VRAM used
# 0   Sat Oct  7 05:02:08 2023       NaN  1067986944  1099494850560
# 1   Sat Oct  7 05:02:09 2023  0.000000  1067986944  1099494850560
# 2   Sat Oct  7 05:02:10 2023  0.000000  1067995136  1099494850560
# 3   Sat Oct  7 05:02:11 2023  0.000000  1067995136  1099494850560
# 4   Sat Oct  7 05:02:12 2023  0.000000  1067995136  1099494850560
# ..                       ...       ...         ...            ...
# 72  Sat Oct  7 05:03:20 2023  0.249377  1068253184  1099494850560
# 73  Sat Oct  7 05:03:21 2023  0.000000  1068253184  1099494850560
# 74  Sat Oct  7 05:03:22 2023  0.000000  1068253184  1099494850560
# 75  Sat Oct  7 05:03:23 2023  0.000000  1068253184  1099494850560
# 76  Sat Oct  7 05:03:24 2023  0.250000  1068253184  1099494850560
#
# [77 rows x 4 columns]

# %%
sys21r2.dropna(subset=['CPU used'], inplace=True)

# %%
sys21r2['Time'] = pd.to_datetime(sys21r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
plt.plot(sys21r2['Time'], sys21r2['CPU used'], label='CPU used', marker='o')
#plt.plot(sys21r2['Time'], sys21r2['RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('CPU Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys21r2
# Out:
#                   Time  CPU used    RAM used      VRAM used
# 1  2023-10-07 05:02:09  0.000000  1067986944  1099494850560
# 2  2023-10-07 05:02:10  0.000000  1067995136  1099494850560
# 3  2023-10-07 05:02:11  0.000000  1067995136  1099494850560
# 4  2023-10-07 05:02:12  0.000000  1067995136  1099494850560
# 5  2023-10-07 05:02:13  0.000000  1067995136  1099494850560
# ..                 ...       ...         ...            ...
# 72 2023-10-07 05:03:20  0.249377  1068253184  1099494850560
# 73 2023-10-07 05:03:21  0.000000  1068253184  1099494850560
# 74 2023-10-07 05:03:22  0.000000  1068253184  1099494850560
# 75 2023-10-07 05:03:23  0.000000  1068253184  1099494850560
# 76 2023-10-07 05:03:24  0.250000  1068253184  1099494850560
#
# [76 rows x 4 columns]

# %%
sys21r2.describe()
# Out:
#         CPU used      RAM used     VRAM used
# count  76.000000  7.600000e+01  7.600000e+01
# mean    0.112231  1.068056e+09  1.099495e+12
# std     0.266764  1.105011e+05  0.000000e+00
# min     0.000000  1.067987e+09  1.099495e+12
# 25%     0.000000  1.067995e+09  1.099495e+12
# 50%     0.000000  1.067995e+09  1.099495e+12
# 75%     0.000000  1.067995e+09  1.099495e+12
# max     1.259446  1.068253e+09  1.099495e+12

# %% [markdown]
# ****SKENARIO 1****

# %% [markdown]
# **DELAY** **Skenario 1**

# %%
log11.loc[0]["AverageRTT(ms)"]
# Out:
# 14.200292

# %%
log12.loc[0]["AverageRTT(ms)"]
# Out:
# 12.831537

# %%
log13.loc[0]["AverageRTT(ms)"]
# Out:
# 12.532805

# %% [markdown]
# **Throughput Skenario 1**

# %%
Throughput11 = 4096 / log11.loc[0]["AverageRTT(ms)"]
Throughput11
# Out:
# 288.4447728257982

# %%
Throughput12 = 4096 / log12.loc[0]["AverageRTT(ms)"]
Throughput12
# Out:
# 319.2135127693588

# %%
Throughput13 = 4096 / log13.loc[0]["AverageRTT(ms)"]
Throughput13
# Out:
# 326.82228758845287

# %% [markdown]
# **Packet Loss Skenario 1**

# %%
packetloss11=log11.loc[0]["InterestLoss(%)"]
packetloss11
# Out:
# 0.0

# %%
packetloss12=log12.loc[0]["InterestLoss(%)"]
packetloss12
# Out:
# 0.01

# %%
packetloss13=log13.loc[0]["InterestLoss(%)"]
packetloss13
# Out:
# 0.07

# %% [markdown]
# *Cache Hit 1*

# %%
cachehit11= [x for x in log111["rtt(ms)"] if x < 2.44]
ch11 = len(cachehit11)
ch11
# Out:
# 225

# %%
cachehit12= [x for x in log122["rtt(ms)"] if x < 2.44]
ch12 =len(cachehit12)
ch12
# Out:
# 235

# %%
cachehit13= [x for x in log133["rtt(ms)"] if x < 2.44]
ch13 = len(hitratio13)
ch13
# Out:
# 230

# %% [markdown]
# Cache Hit Ration Skenario 1

# %%
CHR11=(ch11/(10000-(packetloss11*10000)))*100
CHR11
# Out:
# 2.25

# %%
CHR12=(ch12/(10000-(packetloss12*10000)))*100
CHR12
# Out:
# 2.3737373737373737

# %%
CHR13=(ch13/(10000-(packetloss13*10000)))*100
CHR13
# Out:
# 2.4731182795698925

# %% [markdown]
# ****SKENARIO 2****

# %% [markdown]
# *Delay 2*

# %%
log21.loc[0]["AverageRTT(ms)"]
# Out:
# 26.446233

# %%
log22.loc[0]["AverageRTT(ms)"]
# Out:
# 29.710016

# %%
log23.loc[0]["AverageRTT(ms)"]
# Out:
# 37.848129

# %% [markdown]
# *Throughput 2*

# %%
Throughput21 = 1024 / log21.loc[0]["AverageRTT(ms)"]
Throughput21
# Out:
# 38.72007026482751

# %%
Throughput22 = 4096 / log22.loc[0]["AverageRTT(ms)"]
Throughput22
# Out:
# 137.86596412469115

# %%
Throughput23 = 8192 / log23.loc[0]["AverageRTT(ms)"]
Throughput23
# Out:
# 216.44398855224784

# %% [markdown]
# *Packet Loss 2*

# %%
packetloss21 = log21.loc[0]["InterestLoss(%)"]
packetloss21
# Out:
# 0.04

# %%
packetloss22 = log22.loc[0]["InterestLoss(%)"]
packetloss22
# Out:
# 0.01

# %%
packetloss23 = log23.loc[0]["InterestLoss(%)"]
packetloss23
# Out:
# 0.04

# %% [markdown]
# Cache hit 2

# %%
hitratio21= [x for x in log211["rtt(ms)"] if x < 2.44]
ch21 = len(hitratio21)
ch21
# Out:
# 85

# %%
hitratio22= [x for x in log222["rtt(ms)"] if x < 2.44]
ch22 = len(hitratio22)
ch22
# Out:
# 212

# %%
hitratio23= [x for x in log233["rtt(ms)"] if x < 2.44]
ch23= len(hitratio23)
ch23
# Out:
# 261

# %% [markdown]
# Cache hit ratio 2

# %%
CHR21=(ch21/(10000-(packetloss21*10000)))*100
CHR21
# Out:
# 0.8854166666666666

# %%
CHR22=(ch22/(10000-(packetloss22*10000)))*100
CHR22
# Out:
# 2.1414141414141414

# %%
CHR23=(ch23/(10000-(packetloss23*10000)))*100
CHR23
# Out:
# 2.71875

# %% [markdown]
# **Skenario 3**

# %% [markdown]
# *Delay 3*

# %%
log31.loc[0]["AverageRTT(ms)"]
# Out:
# 3.959777

# %%
log32.loc[0]["AverageRTT(ms)"]
# Out:
# 4.149797

# %%
log33.loc[0]["AverageRTT(ms)"]
# Out:
# 10.194114

# %% [markdown]
# *Througput 3*

# %%
Throughput31 = 4096 / log31.loc[0]["AverageRTT(ms)"]
Throughput31
# Out:
# 1034.4016847413377

# %%
Throughput32 = 4096 / log32.loc[0]["AverageRTT(ms)"]
Throughput32
# Out:
# 987.0362333386428

# %%
Throughput33 = 4096 / log33.loc[0]["AverageRTT(ms)"]
Throughput33
# Out:
# 401.8004899690154

# %% [markdown]
# *packet loss 3*

# %%
packetloss31 = log31.loc[0]["InterestLoss(%)"]
packetloss31
# Out:
# 0.0

# %%
packetloss32 = log32.loc[0]["InterestLoss(%)"]
packetloss32
# Out:
# 0.0

# %%
packetloss33 = log33.loc[0]["InterestLoss(%)"]
packetloss33
# Out:
# 0.08

# %% [markdown]
# *Cache Hit 3*

# %%
hitratio31= [x for x in log311["rtt(ms)"] if x < 2.44]
ch31=len(hitratio31)
ch31
# Out:
# 7

# %%
hitratio32= [x for x in log322["rtt(ms)"] if x < 2.44]
ch32=len(hitratio32)
ch32
# Out:
# 3

# %%
hitratio33= [x for x in log333["rtt(ms)"] if x < 2.44]
ch33=len(hitratio33)
ch33
# Out:
# 239

# %% [markdown]
# *Cache Hit Ratio 3*

# %%
CHR31=(ch31/(10000-(packetloss31*10000)))*100
CHR31
# Out:
# 0.06999999999999999

# %%
CHR32=(ch32/(10000-(packetloss32*10000)))*100
CHR32
# Out:
# 0.03

# %%
CHR33=(ch33/(10000-(packetloss33*10000)))*100
CHR33
# Out:
# 2.597826086956522

# %%
tinggi = [log11.loc[0]["AverageRTT(ms)"],log12.loc[0]["AverageRTT(ms)"], log13.loc[0]["AverageRTT(ms)"]]
datar = [1,2, 3]

plt.xlabel("Content Size")
tick_label = ["30","60","90"]

plt.bar(datar, tinggi, tick_label = tick_label, width = 0.5)

plt.ylabel("Average RTT")
plt.title("Content Size vs RTT")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Gabungkan DataFrames df1, df2, dan df3
combined_df1 = pd.concat([log11[['PatternID', 'AverageRTT(ms)']], log12[['PatternID', 'AverageRTT(ms)']], log13[['PatternID', 'AverageRTT(ms)']]], ignore_index=True)

# Membuat line chart dengan warna yang berbeda-beda
plt.figure(figsize=(8, 6))  # Ukuran figur (opsional)

# Daftar warna yang berbeda untuk setiap DataFrame
colors = ['blue', 'green', 'red']

for i, df in enumerate([log11, log12, log13]):
    plt.plot(df['PatternID'], df['AverageRTT(ms)'], marker='o', linestyle='-', color=colors[i], label=f'DF{i+1}')

plt.title('Grafik Line Chart: Waktu vs. TotalRTT(ms)')
plt.xlabel('PatternID')
plt.ylabel('RTT')
plt.grid(True)  # Menampilkan grid (opsional)
plt.legend()  # Menampilkan legenda untuk setiap line
plt.show()

# %% [markdown]
# Skenario 2

# %%
tinggi = [log21.loc[0]["AverageRTT(ms)"],log22.loc[0]["AverageRTT(ms)"], log23.loc[0]["AverageRTT(ms)"]]
datar = [1,2, 3]

plt.xlabel("Content Size")
tick_label = ["1024","4096","8192"]

plt.bar(datar, tinggi, tick_label = tick_label, width = 0.5)

plt.ylabel("Average RTT")
plt.title("Content Size vs RTT")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Gabungkan DataFrames df1, df2, dan df3
combined_df1 = pd.concat([log21[['PatternID', 'AverageRTT(ms)']], log22[['PatternID', 'AverageRTT(ms)']], log23[['PatternID', 'AverageRTT(ms)']]], ignore_index=True)

# Membuat line chart dengan warna yang berbeda-beda
plt.figure(figsize=(8, 6))  # Ukuran figur (opsional)

# Daftar warna yang berbeda untuk setiap DataFrame
colors = ['blue', 'green', 'red']

for i, df in enumerate([log21, log22, log23]):
    plt.plot(df['PatternID'], df['AverageRTT(ms)'], marker='o', linestyle='-', color=colors[i], label=f'DF{i+1}')

plt.title('Grafik Line Chart: Waktu vs. TotalRTT(ms)')
plt.xlabel('PatternID')
plt.ylabel('RTT')
plt.grid(True)  # Menampilkan grid (opsional)
plt.legend()  # Menampilkan legenda untuk setiap line
plt.show()

# %% [markdown]
# Skenario 3

# %%
tinggi = [log31.loc[0]["AverageRTT(ms)"], log32.loc[0]["AverageRTT(ms)"], log33.loc[0]["AverageRTT(ms)"]]
datar = [1,2,3]

plt.xlabel("Rate Interest")
tick_label = ["10","100","1000"]

plt.bar(datar, tinggi, tick_label = tick_label, width = 0.5)

plt.ylabel("Average RTT")
plt.title("Rate Interest vs RTT")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Gabungkan DataFrames df1, df2, dan df3
combined_df1 = pd.concat([log31[['PatternID', 'AverageRTT(ms)']], log32[['PatternID', 'AverageRTT(ms)']], log33[['PatternID', 'AverageRTT(ms)']]], ignore_index=True)

# Membuat line chart dengan warna yang berbeda-beda
plt.figure(figsize=(8, 6))  # Ukuran figur (opsional)

# Daftar warna yang berbeda untuk setiap DataFrame
colors = ['blue', 'green', 'red']

for i, df in enumerate([log31, log32, log33]):
    plt.plot(df['PatternID'], df['AverageRTT(ms)'], marker='o', linestyle='-', color=colors[i], label=f'DF{i+1}')

plt.title('Grafik Line Chart: Waktu vs. TotalRTT(ms)')
plt.xlabel('PatternID')
plt.ylabel('RTT')
plt.grid(True)  # Menampilkan grid (opsional)
plt.legend()  # Menampilkan legenda untuk setiap line
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Gabungkan DataFrames df1, df2, dan df3
combined_df2 = pd.concat([log21[['Urutan', 'TotalRTT(ms)']], log23[['Urutan', 'TotalRTT(ms)']]], ignore_index=True)

# Membuat line chart dengan warna yang berbeda-beda
plt.figure(figsize=(8, 6))  # Ukuran figur (opsional)

# Daftar warna yang berbeda untuk setiap DataFrame
colors = ['blue', 'red']

for i, df in enumerate([log21, log23]):
    plt.plot(df['Urutan'], df['TotalRTT(ms)'], marker='o', linestyle='-', color=colors[i], label=f'DF{i+1}')

plt.title('Grafik Line Chart: Waktu vs. TotalRTT(ms)')
plt.xlabel('Urutan')
plt.ylabel('RTT')
plt.grid(True)  # Menampilkan grid (opsional)
plt.legend()  # Menampilkan legenda untuk setiap line
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-a595acc6819a> in <cell line: 5>()
#       3
#       4 # Gabungkan DataFrames df1, df2, dan df3
# ----> 5 combined_df2 = pd.concat([log21[['Urutan', 'TotalRTT(ms)']], log23[['Urutan', 'TotalRTT(ms)']]], ignore_index=True)
#       6
#       7 # Membuat line chart dengan warna yang berbeda-beda
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
import pandas as pd

# Tambahkan kolom baru dengan urutan 1, 2, 3, ...
log31['Urutan'] = range(1, len(log31) + 1)
log32['Urutan'] = range(1, len(log32) + 1)
log33['Urutan'] = range(1, len(log33) + 1)

# Tampilkan DataFrame hasil
print(log11)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Gabungkan DataFrames df1, df2, dan df3
combined_df3 = pd.concat([log31[['Urutan', 'TotalRTT(ms)']], log32[['Urutan', 'TotalRTT(ms)']], log33[['Urutan', 'TotalRTT(ms)']]], ignore_index=True)

# Membuat line chart dengan warna yang berbeda-beda
plt.figure(figsize=(8, 6))  # Ukuran figur (opsional)

# Daftar warna yang berbeda untuk setiap DataFrame
colors = ['blue', 'green', 'red']

for i, df in enumerate([log31, log32, log33]):
    plt.plot(df['Urutan'], df['TotalRTT(ms)'], marker='o', linestyle='-', color=colors[i], label=f'DF{i+1}')

plt.title('Grafik Line Chart: Waktu vs. TotalRTT(ms)')
plt.xlabel('Urutan')
plt.ylabel('RTT')
plt.grid(True)  # Menampilkan grid (opsional)
plt.legend()  # Menampilkan legenda untuk setiap line
plt.show()

# %%
import pandas as pd

# Tambahkan kolom baru dengan urutan 1, 2, 3, ...
interest11['Urutan'] = range(1, len(interest11) + 1)
interest12['Urutan'] = range(1, len(interest12) + 1)
interest13['Urutan'] = range(1, len(interest13) + 1)

# Tampilkan DataFrame hasil
print(interest13)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Gabungkan DataFrames df1, df2, dan df3
combined_df3 = pd.concat([interest11[['Urutan', 'rtt(ms)']], interest12[['Urutan', 'rtt(ms)']], interest13[['Urutan', 'rtt(ms)']]], ignore_index=True)

# Membuat line chart dengan warna yang berbeda-beda
plt.figure(figsize=(10, 6))  # Ukuran figur (opsional)

# Daftar warna yang berbeda untuk setiap DataFrame
colors = ['blue', 'green', 'red']

for i, df in enumerate([interest11, interest12, interest13]):
    plt.plot(df['Urutan'], df['rtt(ms)'], marker='o', linestyle='-', color=colors[i], label=f'DF{i+1}')

plt.title('Grafik Line Chart: Waktu vs. rtt(ms)')
plt.xlabel('Urutan')
plt.ylabel('RTT')
plt.grid(True)  # Menampilkan grid (opsional)
plt.legend()  # Menampilkan legenda untuk setiap line
plt.show()

# %%
import pandas as pd

# Tambahkan kolom baru dengan urutan 1, 2, 3, ...
interest21['Urutan'] = range(1, len(interest21) + 1)
interest23['Urutan'] = range(1, len(interest23) + 1)

# Tampilkan DataFrame hasil
print(interest23)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Gabungkan DataFrames df1, df2, dan df3
combined_df3 = pd.concat([interest21[['Urutan', 'rtt(ms)']], interest23[['Urutan', 'rtt(ms)']]], ignore_index=True)

# Membuat line chart dengan warna yang berbeda-beda
plt.figure(figsize=(10, 6))  # Ukuran figur (opsional)

# Daftar warna yang berbeda untuk setiap DataFrame
colors = ['blue', 'red']

for i, df in enumerate([interest21, interest23]):
    plt.plot(df['Urutan'], df['rtt(ms)'], marker='o', linestyle='-', color=colors[i], label=f'DF{i+1}')

plt.title('Grafik Line Chart: Waktu vs. rtt(ms)')
plt.xlabel('Urutan')
plt.ylabel('RTT')
plt.grid(True)  # Menampilkan grid (opsional)
plt.legend()  # Menampilkan legenda untuk setiap line
plt.show()

# %%
import pandas as pd

# Tambahkan kolom baru dengan urutan 1, 2, 3, ...
interest31['Urutan'] = range(1, len(interest31) + 1)
interest32['Urutan'] = range(1, len(interest32) + 1)
interest33['Urutan'] = range(1, len(interest33) + 1)

# Tampilkan DataFrame hasil
print(interest33)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Gabungkan DataFrames df1, df2, dan df3
combined_df3 = pd.concat([interest31[['Urutan', 'rtt(ms)']], interest32[['Urutan', 'rtt(ms)']], interest33[['Urutan', 'rtt(ms)']]], ignore_index=True)

# Membuat line chart dengan warna yang berbeda-beda
plt.figure(figsize=(10, 6))  # Ukuran figur (opsional)

# Daftar warna yang berbeda untuk setiap DataFrame
colors = ['blue', 'green', 'red']

for i, df in enumerate([interest31, interest32, interest33]):
    plt.plot(df['Urutan'], df['rtt(ms)'], marker='o', linestyle='-', color=colors[i], label=f'DF{i+1}')

plt.title('Grafik Line Chart: Waktu vs. rtt(ms)')
plt.xlabel('Urutan')
plt.ylabel('RTT')
plt.grid(True)  # Menampilkan grid (opsional)
plt.legend()  # Menampilkan legenda untuk setiap line
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-568328ad-fa4a-4441-96cc-75a3d18ca9df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-568328ad-fa4a-4441-96cc-75a3d18ca9df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sys31r2=pd.read_csv("skenario3-1 (2).csv", index_col=False)
sys31r2.dropna(subset=['CPU used'], inplace=True)
sys31r2['Time'] = pd.to_datetime(sys31r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys31r2['Time'], sys31r2['CPU used'], label='CPU used', marker='o')
plt.plot(sys31r2['Time'], sys31r2[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys32r2=pd.read_csv("skenario3-2 (1).csv", index_col=False)
sys32r2.dropna(subset=['CPU used'], inplace=True)
sys32r2['Time'] = pd.to_datetime(sys32r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys31r2['Time'], sys31r2['CPU used'], label='CPU used', marker='o')
plt.plot(sys32r2['Time'], sys32r2[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()

# %%
sys33r2=pd.read_csv("skenario3-3 (1).csv", index_col=False)
sys33r2.dropna(subset=['CPU used'], inplace=True)
sys33r2['Time'] = pd.to_datetime(sys33r2['Time'])

# Membuat plot line untuk kolom 'CPU used' dan 'Ram used'
plt.figure(figsize=(10, 6))
#plt.plot(sys31r2['Time'], sys31r2['CPU used'], label='CPU used', marker='o')
plt.plot(sys33r2['Time'], sys33r2[' RAM used'], label='Ram used', marker='o')

# Menambahkan label dan judul
plt.xlabel('Time')
plt.ylabel('Usage')
plt.title('RAM Over Time')

# Menambahkan legenda
plt.legend()

# Menampilkan grafik
plt.grid(True)
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih terbaca
plt.tight_layout()
plt.show()
